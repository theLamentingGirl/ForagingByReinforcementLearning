# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=78)
print(p1[p1.Length<7])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#       4
#       5 p1 = pd.read_csv('data/1.csv',skiprows=78)
# ----> 6 print(p1[p1.Length<7])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Length'

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=78)
print(p1[p1.length<7])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#       4
#       5 p1 = pd.read_csv('data/1.csv',skiprows=78)
# ----> 6 print(p1[p1.length<7])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'length'

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=78)
print(p1.iloc[1,1:5])
# Out:
# 1      3
# 54    43
# Name: 1, dtype: object

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=78)
print(p1.iloc[0,0:5])
# Out:
# 4      4
# 1      2
# 54    48
# Name: 0, dtype: object

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=78)
print(p1.iloc[0,0:10])
# Out:
# 4      4
# 1      2
# 54    48
# Name: 0, dtype: object

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=78)
print(p1.iloc[0:5,0])
# Out:
# 0    4
# 1    4
# 2    5
# 3    6
# 4    6
# Name: 4, dtype: object

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=78)
print(p1.iloc[0:5,0:1])
# Out:
#    4
# 0  4
# 1  4
# 2  5
# 3  6
# 4  6

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=77)
print(p1.iloc[0:5,0:1])
# Out:
#    3
# 0  4
# 1  4
# 2  4
# 3  5
# 4  6

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=76,header=77)
print(p1.iloc[0:5,0:1])
# Out:
#    4
# 0  4
# 1  2
# 2  2
# 3  2
# 4  2

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,header=76)
print(p1.iloc[0:5,0:1])
# Out:
#    4
# 0  4
# 1  4
# 2  2
# 3  2
# 4  2

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,header=76)
# print(p1.iloc[0:5,0:1])
print(p1)
# Out:
#               4    15       63
# 0             4  16.0     57.0
# 1             4  17.0     51.0
# 2             2  21.0    153.0
# 3             2  22.0    137.0
# 4             2  23.0    119.0
# ..          ...   ...      ...
# 553          -1  -1.0  21621.0
# 554  difficulty   NaN      NaN
# 555           2   NaN      NaN
# 556           2   NaN      NaN
# 557           2   NaN      NaN
#
# [558 rows x 3 columns]

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75)
# print(p1.iloc[0:5,0:1])
print(p1)
# Out:
#              id   exploit   reward
# 0             3       1.0      0.0
# 1             4       1.0     54.0
# 2             4       2.0     48.0
# 3             4       3.0     43.0
# 4             5       1.0      0.0
# ..          ...       ...      ...
# 629          -1      -1.0  21621.0
# 630  difficulty       NaN      NaN
# 631           2       NaN      NaN
# 632           2       NaN      NaN
# 633           2       NaN      NaN
#
# [634 rows x 3 columns]

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75)

print(p1)
print(p1.iloc[0:5,0])
# Out:
#              id   exploit   reward
# 0             3       1.0      0.0
# 1             4       1.0     54.0
# 2             4       2.0     48.0
# 3             4       3.0     43.0
# 4             5       1.0      0.0
# ..          ...       ...      ...
# 629          -1      -1.0  21621.0
# 630  difficulty       NaN      NaN
# 631           2       NaN      NaN
# 632           2       NaN      NaN
# 633           2       NaN      NaN
#
# [634 rows x 3 columns]
# 0    3
# 1    4
# 2    4
# 3    4
# 4    5
# Name: id, dtype: object

# %%
col1 = p1.groupby['1'].sum()
print(col1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
# ----> 1 col1 = p1.groupby['1'].sum()
#       2 print(col1)
#
# TypeError: 'method' object is not subscriptable

# %%
col1 = p1.groupby(['1']).sum()
print(col1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
# ----> 1 col1 = p1.groupby(['1']).sum()
#       2 print(col1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6523             squeeze=squeeze,
#    6524             observed=observed,
# -> 6525             dropna=dropna,
#    6526         )
#    6527
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
#     532                 mutated=self.mutated,
# --> 533                 dropna=self.dropna,
#     534             )
#     535
#
# ...

# %%
col1 = p1.groupby(['id']).sum()
print(col1)
# Out:
#              exploit   reward
# id
# -1              -3.0  57536.0
# 0               73.0    795.0
# 1             1487.0   4736.0
# 2             5034.0  12480.0
# 3             2545.0   7878.0
# 4             3692.0  11985.0
# 5              107.0    943.0
# 6             3605.0  11686.0
# 7             2487.0   7033.0
# difficulty       0.0      0.0

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=200)
p2 = pd.read_csv('data/2.csv',skiprows=75)
p3 = pd.read_csv('data/3.csv',skiprows=75)
p4 = pd.read_csv('data/4.csv',skiprows=75)
p5 = pd.read_csv('data/5.csv',skiprows=75)
p6 = pd.read_csv('data/6.csv',skiprows=75)
p7 = pd.read_csv('data/7.csv',skiprows=75)
p8 = pd.read_csv('data/8.csv',skiprows=75)
p9 = pd.read_csv('data/9.csv',skiprows=75)
p10 = pd.read_csv('data/10.csv',skiprows=75)
p11 = pd.read_csv('data/11.csv',skiprows=75)
p12 = pd.read_csv('data/12.csv',skiprows=75)
p13 = pd.read_csv('data/13.csv',skiprows=75)

# print(p1)
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
print(col1)
# Out:
#      exploit   reward
# id
# -1        -1    17168
#  0         7        0
#  1      1485     4736
#  2      1378     3956
#  3         1        0
#  4       990     4278
#  5         1        0
#  6       903     4198
#  7         1        0

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=200)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75)
p4 = pd.read_csv('data/4.csv',skiprows=75)
p5 = pd.read_csv('data/5.csv',skiprows=75)
p6 = pd.read_csv('data/6.csv',skiprows=75)
p7 = pd.read_csv('data/7.csv',skiprows=75)
p8 = pd.read_csv('data/8.csv',skiprows=75)
p9 = pd.read_csv('data/9.csv',skiprows=75)
p10 = pd.read_csv('data/10.csv',skiprows=75)
p11 = pd.read_csv('data/11.csv',skiprows=75)
p12 = pd.read_csv('data/12.csv',skiprows=75)
p13 = pd.read_csv('data/13.csv',skiprows=75)

# print(p1)
# print(p1.iloc[0:5,0])

# %%
col1 = p2.groupby(['id']).sum()
print(col1)
# Out:
#      exploit   reward
# id
# -1        -1    14997
#  0         1        0
#  1       780     3356
#  2       741     3958
#  3         4       58
#  4       780     3489
#  5         1        0
#  6      1326     4194
#  7         1        0

# %%
col1 = p1.groupby(['id']).sum()
print(col1)
# Out:
#      exploit   reward
# id
# -1        -1    17168
#  0         7        0
#  1      1485     4736
#  2      1378     3956
#  3         1        0
#  4       990     4278
#  5         1        0
#  6       903     4198
#  7         1        0

# %%
col1 = p10.groupby(['id']).sum()
print(col1)
# Out:
#              exploit   reward
# id
# -1              -3.0  46268.0
# 0              520.0   2399.0
# 1              532.0   2873.0
# 2             1960.0   9415.0
# 3             1445.0   6251.0
# 4             1724.0   7632.0
# 5              572.0   2264.0
# 6             1772.0   9052.0
# 7             1657.0   6382.0
# difficulty       0.0      0.0

# %%
col1 = p11.groupby(['id']).sum()
print(col1)
# Out:
#              exploit   reward
# id
# -1              -3.0  39615.0
# 0              439.0   2065.0
# 1              278.0   2417.0
# 2             1603.0   6700.0
# 3             1490.0   6041.0
# 4             2032.0   8060.0
# 5             1088.0   2623.0
# 6             1496.0   6366.0
# 7             1330.0   5343.0
# difficulty       0.0      0.0

# %%
col1 = p2.groupby(['id']).sum()
print(col1)
# Out:
#      exploit   reward
# id
# -1        -1    14997
#  0         1        0
#  1       780     3356
#  2       741     3958
#  3         4       58
#  4       780     3489
#  5         1        0
#  6      1326     4194
#  7         1        0

# %%
col1 = p1.groupby(['id']).sum()
print(col1)
# Out:
#      exploit   reward
# id
# -1        -1    17168
#  0         7        0
#  1      1485     4736
#  2      1378     3956
#  3         1        0
#  4       990     4278
#  5         1        0
#  6       903     4198
#  7         1        0

# %%
col1 = p3.groupby(['id']).sum()
print(col1)
# Out:
#              exploit   reward
# id
# -1              -3.0  19277.0
# 0              599.0   1529.0
# 1              632.0   1682.0
# 2             1277.0   3636.0
# 3             3148.0   4013.0
# 4             2513.0   4306.0
# 5              505.0   1015.0
# 6              539.0   1608.0
# 7              604.0   1488.0
# difficulty       0.0      0.0

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1)
# print(p1.iloc[0:5,0])

# %%
col1 = p3.groupby(['id']).sum()
print(col1)
# Out:
#      exploit   reward
# id
# -1        -1     4954
#  0         3        0
#  1       630     1682
#  2       780     2112
#  3        11       57
#  4       496      948
#  5         6        0
#  6        10      212
#  7         6        0

# %%
col1 = p1.groupby(['id']).sum()
col1 = p1.groupby(level=[lambda x:x>0])
print(col1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#       1 col1 = p1.groupby(['id']).sum()
# ----> 2 col1 = p1.groupby(level=[lambda x:x>0])
#       3 print(col1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6523             squeeze=squeeze,
#    6524             observed=observed,
# -> 6525             dropna=dropna,
#    6526         )
#    6527
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     531                 observed=observed,
#     532                 mutated=self.mutated,
# --> 533                 dropna=self.dropna,
# ...

# %%
col1 = p1.groupby(['id']).sum()
col1 = p1.iloc[lambda x:x>0,:]
print(col1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#       1 col1 = p1.groupby(['id']).sum()
# ----> 2 col1 = p1.iloc[lambda x:x>0,:]
#       3 print(col1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1447             pass
#    1448
# -> 1449         return self._getitem_tuple_same_dim(tup)
#    1450
#    1451     def _get_list_axis(self, key, axis: int):
#
# ...

# %%
col1 = p1.groupby(['id']).sum()
index = p1[ p1['reward'] == 0 ].index
# Delete these row indexes from dataFrame
col1 = p1.drop(index , inplace=True)
print(col1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reward'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
# ...

# %%
col1 = p1.groupby(['id']).sum()
index = col1[ col1['reward'] == 0 ].index
# Delete these row indexes from dataFrame
col = p1.drop(index , inplace=True)
print(col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reward'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
# ...

# %%
col1 = p1.groupby(['id']).sum()
index = col1[ col1[2] == 0 ].index
# Delete these row indexes from dataFrame
col = p1.drop(index , inplace=True)
print(col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
# ...

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1)
# print(p1.iloc[0:5,0])

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1)
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()

# indices = col1[ col1[2] == 0 ].index
# # Delete these row indexes from dataFrame
# col = p1.drop(index , inplace=True)
print(col1)
# Out:
#      exploit   reward
# id
# -1        -1    17168
#  0         7        0
#  1      1485     4736
#  2      1378     3956
#  3         1        0
#  4       990     4278
#  5         1        0
#  6       903     4198
#  7         1        0

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1)
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()

indices = col1[ col1[2] == 0 ].index
# # Delete these row indexes from dataFrame
col = p1.drop(index , inplace=True)
print(col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
# ...

# %%
col1 = p1.groupby(['id']).sum()

indices = col1[ col1["reward"] == '0' ].index
# # Delete these row indexes from dataFrame
col = p1.drop(indices , inplace=True)
print(col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reward'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
# ...

# %%
col1 = p1.groupby(['id']).sum()

indices = col1[ col1[1] == '0' ].index
# # Delete these row indexes from dataFrame
col = p1.drop(indices , inplace=True)
print(col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
# ...

# %%
col1 = p1.groupby(['id']).sum()

indices = col1[ col1.iloc[1] == '0' ].index
# # Delete these row indexes from dataFrame
col = p1.drop(indices , inplace=True)
print(col)
# Out:
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import scipy
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#       1 col1 = p1.groupby(['id']).sum()
#       2
# ----> 3 indices = col1[ col1.iloc[1] == '0' ].index
#       4 # # Delete these row indexes from dataFrame
#       5 col = p1.drop(indices , inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2895         # Do we have a (boolean) 1d indexer?
#    2896         if com.is_bool_indexer(key):
# -> 2897             return self._getitem_bool_array(key)
#    2898
#    2899         # We are left with two options: a single key, and a collection of keys,
#
# ...

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

print(p1['id'])
# print(p1.iloc[0:5,0])
# Out:
# 0      3
# 1      4
# 2      4
# 3      4
# 4      5
#       ..
# 195    1
# 196    1
# 197    1
# 198   -1
# 199    0
# Name: id, Length: 200, dtype: int64

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
print(type(col1))

# indices = col1[ col1['reward']== '0' ].index
# # # Delete these row indexes from dataFrame
# col = p1.drop(indices , inplace=True)
# print(col)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']
print(p1['reward'])

# indices = col1[ col1['reward']== '0' ].index
# # # Delete these row indexes from dataFrame
# col = p1.drop(indices , inplace=True)
# print(col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reward'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
# ...

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']
print(col1['reward'])

# indices = col1[ col1['reward']== '0' ].index
# # # Delete these row indexes from dataFrame
# col = p1.drop(indices , inplace=True)
# print(col)
# Out:
# id
# -1    17168
#  0        0
#  1     4736
#  2     3956
#  3        0
#  4     4278
#  5        0
#  6     4198
#  7        0
# Name: reward, dtype: int64

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

indices = col1[ col1['reward']== '0' ].index
# # Delete these row indexes from dataFrame
col = p1.drop(indices , inplace=True)
print(col)
# Out:
# None

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

indices = col1[ col1['reward']== 0 ].index
# # Delete these row indexes from dataFrame
col = p1.drop(indices , inplace=True)
print(col)
# Out:
# None

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

indices = col1[ col1['reward']== 0 ].index
print(indices)
# # Delete these row indexes from dataFrame
# col = p1.drop(indices , inplace=True)
# print(col)
# Out:
# Int64Index([0, 3, 5, 7], dtype='int64', name='id')

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

indices = col1[ col1['reward']== 0 ].index
print(indices)
# # Delete these row indexes from dataFrame
col = col1.drop(indices,inplace=True)
print(col)
# Out:
# Int64Index([0, 3, 5, 7], dtype='int64', name='id')
# None

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

# indices = col1[ col1['reward']== 0 ].index
# print(indices)
# # Delete these row indexes from dataFrame
# col = col1.drop(indices,inplace=True)

col = p1.drop(p1.loc[p1['reward']==0].index, inplace=True)

print(col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reward'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
# ...

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

# indices = col1[ col1['reward']== 0 ].index
# print(indices)
# # Delete these row indexes from dataFrame
# col = col1.drop(indices,inplace=True)

col = col1.drop(col1.loc[col1['reward']==0].index, inplace=True)

print(col)
# Out:
# None

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

# indices = col1[ col1['reward']== 0 ].index
# print(indices)
# # Delete these row indexes from dataFrame
# col = col1.drop(indices,inplace=True)

col1.drop(col1.loc[col1['reward']==0].index, inplace=True)

print(col1)
# Out:
#     exploit  reward
# id
# -1       -1   17168
#  1     1485    4736
#  2     1378    3956
#  4      990    4278
#  6      903    4198

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=274-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

# indices = col1[ col1['reward']== 0 ].index
# print(indices)
# # Delete these row indexes from dataFrame
# col = col1.drop(indices,inplace=True)

col1.drop(col1.loc[col1['reward']==0].index, inplace=True)

print(col1)
# Out:
#     exploit  reward
# id
# -1       -1   17168
#  1     1485    4736
#  2     1378    3956
#  4      990    4278
#  6      903    4198

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-74)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

# indices = col1[ col1['reward']== 0 ].index
# print(indices)
# # Delete these row indexes from dataFrame
# col = col1.drop(indices,inplace=True)

col1.drop(col1.loc[col1['reward']==0].index, inplace=True)

print(col1)
# Out:
#     exploit  reward
# id
# -1       -1   17168
#  1     1485    4736
#  2     1378    3956
#  4      990    4278
#  6      903    4198
#  7        2      63

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=274-74)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

# indices = col1[ col1['reward']== 0 ].index
# print(indices)
# # Delete these row indexes from dataFrame
# col = col1.drop(indices,inplace=True)

col1.drop(col1.loc[col1['reward']==0].index, inplace=True)

print(col1)
# Out:
#     exploit  reward
# id
# -1       -1   17168
#  1     1485    4736
#  2     1378    3956
#  4      990    4278
#  6      903    4198

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=273-73)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

# indices = col1[ col1['reward']== 0 ].index
# print(indices)
# # Delete these row indexes from dataFrame
# col = col1.drop(indices,inplace=True)

col1.drop(col1.loc[col1['reward']==0].index, inplace=True)

print(col1)
# Out:
#     exploit  reward
# id
# -1       -1   17168
#  1     1485    4736
#  2     1378    3956
#  4      990    4278
#  6      903    4198

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=274-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

col1.drop(col1.loc[col1['reward']==0].index, inplace=True)

print(col1)
# Out:
#     exploit  reward
# id
# -1       -1   17168
#  1     1485    4736
#  2     1378    3956
#  4      990    4278
#  6      903    4198

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=274-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

col1.drop(col1.loc[col1['reward']==0].index, inplace=True)

print(col1)
# Out:
#     exploit  reward
# id
# -1       -1   17168
#  1     1485    4736
#  2     1378    3956
#  4      990    4278
#  6      903    4198

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=274-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

col1.drop(col1.loc[col1['reward']==0].index, inplace=True)

print(col1)
# Out:
#     exploit  reward
# id
# -1       -1   17168
#  1     1485    4736
#  2     1378    3956
#  4      990    4278
#  6      903    4198

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
col1 = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']

col1.drop(col1.loc[col1['reward']==0].index, inplace=True)

print(col1)
# Out:
#     exploit  reward
# id
# -1       -1   17168
#  1     1485    4736
#  2     1378    3956
#  4      990    4278
#  6      903    4198

# %%
person1_reward = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']
col1.drop(col1.loc[col1['reward']==0].index, inplace=True)

reward1
print(col1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#       3 col1.drop(col1.loc[col1['reward']==0].index, inplace=True)
#       4
# ----> 5 reward1
#       6 print(col1)
#
# NameError: name 'reward1' is not defined

# %%
person1_reward = p1.groupby(['id']).sum()
col1.columns=['exploit','reward']
col1.drop(col1.loc[col1['reward']==0].index, inplace=True)

reward1
print(col1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#       3 col1.drop(col1.loc[col1['reward']==0].index, inplace=True)
#       4
# ----> 5 reward1
#       6 print(col1)
#
# NameError: name 'reward1' is not defined

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit','reward']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward']==0].index, inplace=True)

reward1 = p1_filtered['reward']
print(reward1)
# Out:
# id
# -1    17168
#  1     4736
#  2     3956
#  4     4278
#  6     4198
# Name: reward, dtype: int64

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit','reward']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit','reward']
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward']==0].index, inplace=True)

reward1 = p1_filtered.iloc[1:,0]
# reward2
print(reward1)
# Out:
# id
# 1    1485
# 2    1378
# 4     990
# 6     903
# Name: exploit, dtype: int64

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit','reward']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit','reward']
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward']==0].index, inplace=True)

reward1 = p1_filtered.iloc[1:,0]
reward2 = p2_filtered.iloc[1:,0]
pd.concat([reward1,reward2],axis=1])# %%
# Out:
#   File "<ipython-input-12-77aadfc62e2c>", line 12
#     pd.concat([reward1,reward2],axis=1])# %%
#                                       ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit','reward']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit','reward']
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward']==0].index, inplace=True)

reward1 = p1_filtered.iloc[1:,0]
reward2 = p2_filtered.iloc[1:,0]
print(pd.concat([reward1,reward2],axis=1))
# Out:
#     exploit  exploit
# id
# 1    1485.0      780
# 2    1378.0      741
# 3       NaN        4
# 4     990.0      780
# 6     903.0     1326

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit','reward']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit','reward']
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward']==0].index, inplace=True)

reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
print(pd.concat([reward1,reward2],axis=1))
# Out:
#     reward  reward
# id
# 1   4736.0    3356
# 2   3956.0    3958
# 3      NaN      58
# 4   4278.0    3489
# 6   4198.0    4194

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit','reward']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit','reward']
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward']==0].index, inplace=True)

reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
print(pd.concat([reward1,reward2],axis=2))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#      10 reward1 = p1_filtered.iloc[1:,1]
#      11 reward2 = p2_filtered.iloc[1:,1]
# ---> 12 print(pd.concat([reward1,reward2],axis=2))
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282         verify_integrity=verify_integrity,
#     283         copy=copy,
# ...

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit','reward']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit','reward']
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward']==0].index, inplace=True)

reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
print(pd.concat([reward1,reward2],axis=0))
# Out:
# id
# 1    4736
# 2    3956
# 4    4278
# 6    4198
# 1    3356
# 2    3958
# 3      58
# 4    3489
# 6    4194
# Name: reward, dtype: int64

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit','reward']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit','reward']
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward']==0].index, inplace=True)

reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
print(pd.concat([reward1,reward2],axis=1 ))
# Out:
#     reward  reward
# id
# 1   4736.0    3356
# 2   3956.0    3958
# 3      NaN      58
# 4   4278.0    3489
# 6   4198.0    4194

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit','reward']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit','reward']
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward']==0].index, inplace=True)

reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
print(pd.concat([reward1,reward2],axis=1 ).T)
# Out:
# id           1       2     3       4       6
# reward  4736.0  3956.0   NaN  4278.0  4198.0
# reward  3356.0  3958.0  58.0  3489.0  4194.0

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit_p1','reward_p1']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit_p2','reward_p2']
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward']==0].index, inplace=True)

p3_filtered = p3.groupby(['id']).sum()
p3_filtered.columns=['exploit_p3','reward_p3']
p3_filtered.drop(p3_filtered.loc[p3_filtered['reward']==0].index, inplace=True)

p4_filtered = p4.groupby(['id']).sum()
p4_filtered.columns=['exploit_p4','reward_p4']
p4_filtered.drop(p4_filtered.loc[p4_filtered['reward']==0].index, inplace=True)

p5_filtered = p5.groupby(['id']).sum()
p5_filtered.columns=['exploit_p5','reward_p5']
p5_filtered.drop(p5_filtered.loc[p5_filtered['reward']==0].index, inplace=True)

p6_filtered = p6.groupby(['id']).sum()
p6_filtered.columns=['exploit_p6','reward_p6']
p6_filtered.drop(p6_filtered.loc[p6_filtered['reward']==0].index, inplace=True)

p7_filtered = p7.groupby(['id']).sum()
p7_filtered.columns=['exploit_p7','reward_p7']
p7_filtered.drop(p7_filtered.loc[p7_filtered['reward']==0].index, inplace=True)

p8_filtered = p8.groupby(['id']).sum()
p8_filtered.columns=['exploit_p8','reward_p8']
p8_filtered.drop(p8_filtered.loc[p8_filtered['reward']==0].index, inplace=True)

p9_filtered = p9.groupby(['id']).sum()
p9_filtered.columns=['exploit_p9','reward_p9']
p9_filtered.drop(p9_filtered.loc[p9_filtered['reward']==0].index, inplace=True)

p10_filtered = p10.groupby(['id']).sum()
p10_filtered.columns=['exploit_p10','reward_p10']
p10_filtered.drop(p10_filtered.loc[p10_filtered['reward']==0].index, inplace=True)

p11_filtered = p11.groupby(['id']).sum()
p11_filtered.columns=['exploit_p11','reward_p11']
p11_filtered.drop(p11_filtered.loc[p11_filtered['reward']==0].index, inplace=True)

p12_filtered = p12.groupby(['id']).sum()
p12_filtered.columns=['exploit_p12','reward_p12']
p12_filtered.drop(p12_filtered.loc[p12_filtered['reward']==0].index, inplace=True)

p13_filtered = p13.groupby(['id']).sum()
p13_filtered.columns=['exploit_p13','reward_p13']
p13_filtered.drop(p13_filtered.loc[p13_filtered['reward']==0].index, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reward'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
# ...

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit_p1','reward_p1']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward_p1']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit_p2','reward_p2']
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward']==0].index, inplace=True)

p3_filtered = p3.groupby(['id']).sum()
p3_filtered.columns=['exploit_p3','reward_p3']
p3_filtered.drop(p3_filtered.loc[p3_filtered['reward']==0].index, inplace=True)

p4_filtered = p4.groupby(['id']).sum()
p4_filtered.columns=['exploit_p4','reward_p4']
p4_filtered.drop(p4_filtered.loc[p4_filtered['reward']==0].index, inplace=True)

p5_filtered = p5.groupby(['id']).sum()
p5_filtered.columns=['exploit_p5','reward_p5']
p5_filtered.drop(p5_filtered.loc[p5_filtered['reward']==0].index, inplace=True)

p6_filtered = p6.groupby(['id']).sum()
p6_filtered.columns=['exploit_p6','reward_p6']
p6_filtered.drop(p6_filtered.loc[p6_filtered['reward']==0].index, inplace=True)

p7_filtered = p7.groupby(['id']).sum()
p7_filtered.columns=['exploit_p7','reward_p7']
p7_filtered.drop(p7_filtered.loc[p7_filtered['reward']==0].index, inplace=True)

p8_filtered = p8.groupby(['id']).sum()
p8_filtered.columns=['exploit_p8','reward_p8']
p8_filtered.drop(p8_filtered.loc[p8_filtered['reward']==0].index, inplace=True)

p9_filtered = p9.groupby(['id']).sum()
p9_filtered.columns=['exploit_p9','reward_p9']
p9_filtered.drop(p9_filtered.loc[p9_filtered['reward']==0].index, inplace=True)

p10_filtered = p10.groupby(['id']).sum()
p10_filtered.columns=['exploit_p10','reward_p10']
p10_filtered.drop(p10_filtered.loc[p10_filtered['reward']==0].index, inplace=True)

p11_filtered = p11.groupby(['id']).sum()
p11_filtered.columns=['exploit_p11','reward_p11']
p11_filtered.drop(p11_filtered.loc[p11_filtered['reward']==0].index, inplace=True)

p12_filtered = p12.groupby(['id']).sum()
p12_filtered.columns=['exploit_p12','reward_p12']
p12_filtered.drop(p12_filtered.loc[p12_filtered['reward']==0].index, inplace=True)

p13_filtered = p13.groupby(['id']).sum()
p13_filtered.columns=['exploit_p13','reward_p13']
p13_filtered.drop(p13_filtered.loc[p13_filtered['reward']==0].index, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reward'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
# ...

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit_p1','reward_p1']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward_p1']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit_p2','reward_p2']
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward_p2']==0].index, inplace=True)

p3_filtered = p3.groupby(['id']).sum()
p3_filtered.columns=['exploit_p3','reward_p3']
p3_filtered.drop(p3_filtered.loc[p3_filtered['reward_p3']==0].index, inplace=True)

p4_filtered = p4.groupby(['id']).sum()
p4_filtered.columns=['exploit_p4','reward_p4']
p4_filtered.drop(p4_filtered.loc[p4_filtered['reward_p4']==0].index, inplace=True)

p5_filtered = p5.groupby(['id']).sum()
p5_filtered.columns=['exploit_p5','reward_p5']
p5_filtered.drop(p5_filtered.loc[p5_filtered['reward_p5']==0].index, inplace=True)

p6_filtered = p6.groupby(['id']).sum()
p6_filtered.columns=['exploit_p6','reward_p6']
p6_filtered.drop(p6_filtered.loc[p6_filtered['reward_p6']==0].index, inplace=True)

p7_filtered = p7.groupby(['id']).sum()
p7_filtered.columns=['exploit_p7','reward_p7']
p7_filtered.drop(p7_filtered.loc[p7_filtered['reward_p7']==0].index, inplace=True)

p8_filtered = p8.groupby(['id']).sum()
p8_filtered.columns=['exploit_p8','reward_p8']
p8_filtered.drop(p8_filtered.loc[p8_filtered['reward_p8']==0].index, inplace=True)

p9_filtered = p9.groupby(['id']).sum()
p9_filtered.columns=['exploit_p9','reward_p9']
p9_filtered.drop(p9_filtered.loc[p9_filtered['reward_p9']==0].index, inplace=True)

p10_filtered = p10.groupby(['id']).sum()
p10_filtered.columns=['exploit_p10','reward_p10']
p10_filtered.drop(p10_filtered.loc[p10_filtered['reward_p10']==0].index, inplace=True)

p11_filtered = p11.groupby(['id']).sum()
p11_filtered.columns=['exploit_p11','reward_p11']
p11_filtered.drop(p11_filtered.loc[p11_filtered['reward_p11']==0].index, inplace=True)

p12_filtered = p12.groupby(['id']).sum()
p12_filtered.columns=['exploit_p12','reward_p12']
p12_filtered.drop(p12_filtered.loc[p12_filtered['reward_p12']==0].index, inplace=True)

p13_filtered = p13.groupby(['id']).sum()
p13_filtered.columns=['exploit_p13','reward_p13']
p13_filtered.drop(p13_filtered.loc[p13_filtered['reward_p13']==0].index, inplace=True)

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

print(pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T)
# Out:
# id               1       2     3       4     5       6
# reward_p1   4736.0  3956.0   NaN  4278.0   NaN  4198.0
# reward_p2   3356.0  3958.0  58.0  3489.0   NaN  4194.0
# reward_p3   1682.0  2112.0  57.0   948.0   NaN   212.0
# reward_p4   2495.0  2576.0   NaN  3710.0   NaN  2695.0
# reward_p5   2528.0  2375.0   NaN  2480.0   NaN  2528.0
# reward_p6   2723.0  2965.0   NaN  2631.0   NaN  2694.0
# reward_p7   3076.0  2997.0  70.0     NaN   NaN  3113.0
# reward_p8    462.0  3668.0   NaN  3286.0   NaN  1663.0
# reward_p9   2092.0  2115.0   NaN  2616.0   NaN  1622.0
# reward_p10  2873.0  3192.0   NaN  2990.0  56.0  3468.0
# reward_p11  2417.0  2310.0   NaN  2723.0   NaN   321.0
# reward_p12  3844.0  3123.0  55.0  3481.0   NaN  2797.0
# reward_p13  3567.0  2803.0   NaN  2881.0   NaN  2306.0

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

# print(pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T)
print(p1_filtered)
# Out:
#     exploit_p1  reward_p1
# id
# -1          -1      17168
#  1        1485       4736
#  2        1378       3956
#  4         990       4278
#  6         903       4198

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

# print(pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T)
print(p1_filtered.T)
# Out:
# id             -1     1     2     4     6
# exploit_p1     -1  1485  1378   990   903
# reward_p1   17168  4736  3956  4278  4198

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

# print(pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T)
print(p2_filtered.T)
# Out:
# id             -1     1     2   3     4     6
# exploit_p2     -1   780   741   4   780  1326
# reward_p2   14997  3356  3958  58  3489  4194

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

# print(pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T)
print(p12_filtered.T)
# Out:
# id              -1     1     2   3     4     6
# exploit_p12     -1  1176  1770   2   780   435
# reward_p12   13245  3844  3123  55  3481  2797

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

# print(pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T)
print(p2_filtered)
# Out:
#     exploit_p2  reward_p2
# id
# -1          -1      14997
#  1         780       3356
#  2         741       3958
#  3           4         58
#  4         780       3489
#  6        1326       4194

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

# print(pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T)
print(p2_filtered)
print(p2)
# Out:
#     exploit_p2  reward_p2
# id
# -1          -1      14997
#  1         780       3356
#  2         741       3958
#  3           4         58
#  4         780       3489
#  6        1326       4194
#      id   exploit   reward
# 0     3         1        0
# 1     4         1       51
# 2     4         2       44
# 3     4         3       40
# 4     4         4       35
# ..   ..       ...      ...
# 169   6        49       75
# 170   6        50       64
# 171   6        51       56
# 172  -1        -1    14997
# 173   3         1       58
#
# [174 rows x 3 columns]

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit_p1','reward_p1']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward_p1']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit_p2','reward_p2']

print(p2_filtered)
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward_p2']==0].index, inplace=True)
print(p2_filtered)

p3_filtered = p3.groupby(['id']).sum()
p3_filtered.columns=['exploit_p3','reward_p3']
p3_filtered.drop(p3_filtered.loc[p3_filtered['reward_p3']==0].index, inplace=True)

p4_filtered = p4.groupby(['id']).sum()
p4_filtered.columns=['exploit_p4','reward_p4']
p4_filtered.drop(p4_filtered.loc[p4_filtered['reward_p4']==0].index, inplace=True)

p5_filtered = p5.groupby(['id']).sum()
p5_filtered.columns=['exploit_p5','reward_p5']
p5_filtered.drop(p5_filtered.loc[p5_filtered['reward_p5']==0].index, inplace=True)

p6_filtered = p6.groupby(['id']).sum()
p6_filtered.columns=['exploit_p6','reward_p6']
p6_filtered.drop(p6_filtered.loc[p6_filtered['reward_p6']==0].index, inplace=True)

p7_filtered = p7.groupby(['id']).sum()
p7_filtered.columns=['exploit_p7','reward_p7']
p7_filtered.drop(p7_filtered.loc[p7_filtered['reward_p7']==0].index, inplace=True)

p8_filtered = p8.groupby(['id']).sum()
p8_filtered.columns=['exploit_p8','reward_p8']
p8_filtered.drop(p8_filtered.loc[p8_filtered['reward_p8']==0].index, inplace=True)

p9_filtered = p9.groupby(['id']).sum()
p9_filtered.columns=['exploit_p9','reward_p9']
p9_filtered.drop(p9_filtered.loc[p9_filtered['reward_p9']==0].index, inplace=True)

p10_filtered = p10.groupby(['id']).sum()
p10_filtered.columns=['exploit_p10','reward_p10']
p10_filtered.drop(p10_filtered.loc[p10_filtered['reward_p10']==0].index, inplace=True)

p11_filtered = p11.groupby(['id']).sum()
p11_filtered.columns=['exploit_p11','reward_p11']
p11_filtered.drop(p11_filtered.loc[p11_filtered['reward_p11']==0].index, inplace=True)

p12_filtered = p12.groupby(['id']).sum()
p12_filtered.columns=['exploit_p12','reward_p12']
p12_filtered.drop(p12_filtered.loc[p12_filtered['reward_p12']==0].index, inplace=True)

p13_filtered = p13.groupby(['id']).sum()
p13_filtered.columns=['exploit_p13','reward_p13']
p13_filtered.drop(p13_filtered.loc[p13_filtered['reward_p13']==0].index, inplace=True)
# Out:
#     exploit_p2  reward_p2
# id
# -1          -1      14997
#  0           1          0
#  1         780       3356
#  2         741       3958
#  3           4         58
#  4         780       3489
#  5           1          0
#  6        1326       4194
#  7           1          0
#     exploit_p2  reward_p2
# id
# -1          -1      14997
#  1         780       3356
#  2         741       3958
#  3           4         58
#  4         780       3489
#  6        1326       4194

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit_p1','reward_p1']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward_p1']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit_p2','reward_p2']

# print(p2_filtered)
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward_p2']==0].index, inplace=True)
# print(p2_filtered)

p3_filtered = p3.groupby(['id']).sum()
p3_filtered.columns=['exploit_p3','reward_p3']
p3_filtered.drop(p3_filtered.loc[p3_filtered['reward_p3']==0].index, inplace=True)

p4_filtered = p4.groupby(['id']).sum()
p4_filtered.columns=['exploit_p4','reward_p4']
p4_filtered.drop(p4_filtered.loc[p4_filtered['reward_p4']==0].index, inplace=True)

p5_filtered = p5.groupby(['id']).sum()
p5_filtered.columns=['exploit_p5','reward_p5']
p5_filtered.drop(p5_filtered.loc[p5_filtered['reward_p5']==0].index, inplace=True)

p6_filtered = p6.groupby(['id']).sum()
p6_filtered.columns=['exploit_p6','reward_p6']
p6_filtered.drop(p6_filtered.loc[p6_filtered['reward_p6']==0].index, inplace=True)

p7_filtered = p7.groupby(['id']).sum()
p7_filtered.columns=['exploit_p7','reward_p7']
p7_filtered.drop(p7_filtered.loc[p7_filtered['reward_p7']==0].index, inplace=True)

p8_filtered = p8.groupby(['id']).sum()
p8_filtered.columns=['exploit_p8','reward_p8']

print(p8_filtered)
p8_filtered.drop(p8_filtered.loc[p8_filtered['reward_p8']==0].index, inplace=True)
print(p8_filtered)

p9_filtered = p9.groupby(['id']).sum()
p9_filtered.columns=['exploit_p9','reward_p9']
p9_filtered.drop(p9_filtered.loc[p9_filtered['reward_p9']==0].index, inplace=True)

p10_filtered = p10.groupby(['id']).sum()
p10_filtered.columns=['exploit_p10','reward_p10']
p10_filtered.drop(p10_filtered.loc[p10_filtered['reward_p10']==0].index, inplace=True)

p11_filtered = p11.groupby(['id']).sum()
p11_filtered.columns=['exploit_p11','reward_p11']
p11_filtered.drop(p11_filtered.loc[p11_filtered['reward_p11']==0].index, inplace=True)

p12_filtered = p12.groupby(['id']).sum()
p12_filtered.columns=['exploit_p12','reward_p12']
p12_filtered.drop(p12_filtered.loc[p12_filtered['reward_p12']==0].index, inplace=True)

p13_filtered = p13.groupby(['id']).sum()
p13_filtered.columns=['exploit_p13','reward_p13']
p13_filtered.drop(p13_filtered.loc[p13_filtered['reward_p13']==0].index, inplace=True)
# Out:
#     exploit_p8  reward_p8
# id
# -1          -1       9079
#  0           3          0
#  1         137        462
#  2        2145       3668
#  3          15          0
#  4        1431       3286
#  5           3          0
#  6         325       1663
#  7           3          0
#     exploit_p8  reward_p8
# id
# -1          -1       9079
#  1         137        462
#  2        2145       3668
#  4        1431       3286
#  6         325       1663

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

print(pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T)
# print(p2_filtered)
# print()
# Out:
# id               1       2     3       4     5       6
# reward_p1   4736.0  3956.0   NaN  4278.0   NaN  4198.0
# reward_p2   3356.0  3958.0  58.0  3489.0   NaN  4194.0
# reward_p3   1682.0  2112.0  57.0   948.0   NaN   212.0
# reward_p4   2495.0  2576.0   NaN  3710.0   NaN  2695.0
# reward_p5   2528.0  2375.0   NaN  2480.0   NaN  2528.0
# reward_p6   2723.0  2965.0   NaN  2631.0   NaN  2694.0
# reward_p7   3076.0  2997.0  70.0     NaN   NaN  3113.0
# reward_p8    462.0  3668.0   NaN  3286.0   NaN  1663.0
# reward_p9   2092.0  2115.0   NaN  2616.0   NaN  1622.0
# reward_p10  2873.0  3192.0   NaN  2990.0  56.0  3468.0
# reward_p11  2417.0  2310.0   NaN  2723.0   NaN   321.0
# reward_p12  3844.0  3123.0  55.0  3481.0   NaN  2797.0
# reward_p13  3567.0  2803.0   NaN  2881.0   NaN  2306.0

# %%
import numpy as np
import scipy 
import pandas as pd

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit_p1','reward_p1']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward_p1']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit_p2','reward_p2']
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward_p2']==0].index, inplace=True)


p3_filtered = p3.groupby(['id']).sum()
p3_filtered.columns=['exploit_p3','reward_p3']
p3_filtered.drop(p3_filtered.loc[p3_filtered['reward_p3']==0].index, inplace=True)

p4_filtered = p4.groupby(['id']).sum()
p4_filtered.columns=['exploit_p4','reward_p4']
p4_filtered.drop(p4_filtered.loc[p4_filtered['reward_p4']==0].index, inplace=True)

p5_filtered = p5.groupby(['id']).sum()
p5_filtered.columns=['exploit_p5','reward_p5']
p5_filtered.drop(p5_filtered.loc[p5_filtered['reward_p5']==0].index, inplace=True)

p6_filtered = p6.groupby(['id']).sum()
p6_filtered.columns=['exploit_p6','reward_p6']
p6_filtered.drop(p6_filtered.loc[p6_filtered['reward_p6']==0].index, inplace=True)

p7_filtered = p7.groupby(['id']).sum()
p7_filtered.columns=['exploit_p7','reward_p7']
p7_filtered.drop(p7_filtered.loc[p7_filtered['reward_p7']==0].index, inplace=True)

p8_filtered = p8.groupby(['id']).sum()
p8_filtered.columns=['exploit_p8','reward_p8']

print(p8_filtered)
p8_filtered.drop(p8_filtered.loc[p8_filtered['reward_p8']==0].index, inplace=True)
print(p8_filtered)

p9_filtered = p9.groupby(['id']).sum()
p9_filtered.columns=['exploit_p9','reward_p9']
p9_filtered.drop(p9_filtered.loc[p9_filtered['reward_p9']==0].index, inplace=True)

p10_filtered = p10.groupby(['id']).sum()
p10_filtered.columns=['exploit_p10','reward_p10']
p10_filtered.drop(p10_filtered.loc[p10_filtered['reward_p10']==0].index, inplace=True)

p11_filtered = p11.groupby(['id']).sum()
p11_filtered.columns=['exploit_p11','reward_p11']
p11_filtered.drop(p11_filtered.loc[p11_filtered['reward_p11']==0].index, inplace=True)

p12_filtered = p12.groupby(['id']).sum()
p12_filtered.columns=['exploit_p12','reward_p12']
p12_filtered.drop(p12_filtered.loc[p12_filtered['reward_p12']==0].index, inplace=True)

p13_filtered = p13.groupby(['id']).sum()
p13_filtered.columns=['exploit_p13','reward_p13']
p13_filtered.drop(p13_filtered.loc[p13_filtered['reward_p13']==0].index, inplace=True)
# Out:
#     exploit_p8  reward_p8
# id
# -1          -1       9079
#  0           3          0
#  1         137        462
#  2        2145       3668
#  3          15          0
#  4        1431       3286
#  5           3          0
#  6         325       1663
#  7           3          0
#     exploit_p8  reward_p8
# id
# -1          -1       9079
#  1         137        462
#  2        2145       3668
#  4        1431       3286
#  6         325       1663

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T)

pd.dataset.to_csv('reward_per_patch.csv')
# print(p2_filtered)
# print()
# Out:
#   File "<ipython-input-43-f81f4024ef65>", line 15
#     dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T)
#                                                                                                                                                 ^
# SyntaxError: invalid syntax

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T)
print(dataset)
pd.dataset.to_csv('reward_per_patch.csv')
# print(p2_filtered)
# print()
# Out:
#   File "<ipython-input-44-889a4aa47a19>", line 15
#     dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T)
#                                                                                                                                                 ^
# SyntaxError: invalid syntax

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
print(dataset)
pd.dataset.to_csv('reward_per_patch.csv')
# print(p2_filtered)
# print()
# Out:
# id               1       2     3       4     5       6
# reward_p1   4736.0  3956.0   NaN  4278.0   NaN  4198.0
# reward_p2   3356.0  3958.0  58.0  3489.0   NaN  4194.0
# reward_p3   1682.0  2112.0  57.0   948.0   NaN   212.0
# reward_p4   2495.0  2576.0   NaN  3710.0   NaN  2695.0
# reward_p5   2528.0  2375.0   NaN  2480.0   NaN  2528.0
# reward_p6   2723.0  2965.0   NaN  2631.0   NaN  2694.0
# reward_p7   3076.0  2997.0  70.0     NaN   NaN  3113.0
# reward_p8    462.0  3668.0   NaN  3286.0   NaN  1663.0
# reward_p9   2092.0  2115.0   NaN  2616.0   NaN  1622.0
# reward_p10  2873.0  3192.0   NaN  2990.0  56.0  3468.0
# reward_p11  2417.0  2310.0   NaN  2723.0   NaN   321.0
# reward_p12  3844.0  3123.0  55.0  3481.0   NaN  2797.0
# reward_p13  3567.0  2803.0   NaN  2881.0   NaN  2306.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ...

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
print(dataset)
dataset.to_csv('reward_per_patch.csv')
# print(p2_filtered)
# print()
# Out:
# id               1       2     3       4     5       6
# reward_p1   4736.0  3956.0   NaN  4278.0   NaN  4198.0
# reward_p2   3356.0  3958.0  58.0  3489.0   NaN  4194.0
# reward_p3   1682.0  2112.0  57.0   948.0   NaN   212.0
# reward_p4   2495.0  2576.0   NaN  3710.0   NaN  2695.0
# reward_p5   2528.0  2375.0   NaN  2480.0   NaN  2528.0
# reward_p6   2723.0  2965.0   NaN  2631.0   NaN  2694.0
# reward_p7   3076.0  2997.0  70.0     NaN   NaN  3113.0
# reward_p8    462.0  3668.0   NaN  3286.0   NaN  1663.0
# reward_p9   2092.0  2115.0   NaN  2616.0   NaN  1622.0
# reward_p10  2873.0  3192.0   NaN  2990.0  56.0  3468.0
# reward_p11  2417.0  2310.0   NaN  2723.0   NaN   321.0
# reward_p12  3844.0  3123.0  55.0  3481.0   NaN  2797.0
# reward_p13  3567.0  2803.0   NaN  2881.0   NaN  2306.0

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset
rewarding_patches.drop([2,4])

print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#      18
#      19 rewarding_patches = dataset
# ---> 20 rewarding_patches.drop([2,4])
#      21
#      22 print(rewarding_patches)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset
rewarding_patches.drop(columns=[2,4])

print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
# id               1       2     3       4     5       6
# reward_p1   4736.0  3956.0   NaN  4278.0   NaN  4198.0
# reward_p2   3356.0  3958.0  58.0  3489.0   NaN  4194.0
# reward_p3   1682.0  2112.0  57.0   948.0   NaN   212.0
# reward_p4   2495.0  2576.0   NaN  3710.0   NaN  2695.0
# reward_p5   2528.0  2375.0   NaN  2480.0   NaN  2528.0
# reward_p6   2723.0  2965.0   NaN  2631.0   NaN  2694.0
# reward_p7   3076.0  2997.0  70.0     NaN   NaN  3113.0
# reward_p8    462.0  3668.0   NaN  3286.0   NaN  1663.0
# reward_p9   2092.0  2115.0   NaN  2616.0   NaN  1622.0
# reward_p10  2873.0  3192.0   NaN  2990.0  56.0  3468.0
# reward_p11  2417.0  2310.0   NaN  2723.0   NaN   321.0
# reward_p12  3844.0  3123.0  55.0  3481.0   NaN  2797.0
# reward_p13  3567.0  2803.0   NaN  2881.0   NaN  2306.0

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset
rewarding_patches.drop(columns=['2','4'])

print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#      18
#      19 rewarding_patches = dataset
# ---> 20 rewarding_patches.drop(columns=['2','4'])
#      21
#      22 print(rewarding_patches)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset.iloc[0,1,3,5]
print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#      17 # dataset.to_csv('reward_per_patch.csv')
#      18
# ---> 19 rewarding_patches = dataset.iloc[0,1,3,5]
#      20 print(rewarding_patches)
#      21 # print(p2_filtered)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1441     def _getitem_tuple(self, tup: Tuple):
#    1442
# -> 1443         self._has_valid_tuple(tup)
#    1444         try:
# ...

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset.iloc([0,1,3,5])
print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#      17 # dataset.to_csv('reward_per_patch.csv')
#      18
# ---> 19 rewarding_patches = dataset.iloc([0,1,3,5])
#      20 print(rewarding_patches)
#      21 # print(p2_filtered)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     582
#     583         if axis is not None:
# --> 584             axis = self.obj._get_axis_number(axis)
#     585         new_self.axis = axis
#     586         return new_self
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     366     def _get_axis_number(cls, axis: Axis) -> int:
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
# ...

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset
rewarding_patches.drop([2,4])
print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#      18
#      19 rewarding_patches = dataset
# ---> 20 rewarding_patches.drop([2,4])
#      21 print(rewarding_patches)
#      22 # print(p2_filtered)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
# ...

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset
rewarding_patches.drop(columns=['2','4'])
print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#      18
#      19 rewarding_patches = dataset
# ---> 20 rewarding_patches.drop(columns=['2','4'])
#      21 print(rewarding_patches)
#      22 # print(p2_filtered)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
# ...

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset
rewarding patches.columns=['patch1','patch2','patch3','patch4','patch5','patch6']
rewarding_patches.drop(columns=['patch2','patch4'])
print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
#   File "<ipython-input-54-6e3a8300330a>", line 20
#     rewarding patches.columns=['patch1','patch2','patch3','patch4','patch5','patch6']
#                     ^
# SyntaxError: invalid syntax

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset
rewarding_patches.columns=['patch1','patch2','patch3','patch4','patch5','patch6']
rewarding_patches.drop(columns=['patch2','patch4'])
print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
#             patch1  patch2  patch3  patch4  patch5  patch6
# reward_p1   4736.0  3956.0     NaN  4278.0     NaN  4198.0
# reward_p2   3356.0  3958.0    58.0  3489.0     NaN  4194.0
# reward_p3   1682.0  2112.0    57.0   948.0     NaN   212.0
# reward_p4   2495.0  2576.0     NaN  3710.0     NaN  2695.0
# reward_p5   2528.0  2375.0     NaN  2480.0     NaN  2528.0
# reward_p6   2723.0  2965.0     NaN  2631.0     NaN  2694.0
# reward_p7   3076.0  2997.0    70.0     NaN     NaN  3113.0
# reward_p8    462.0  3668.0     NaN  3286.0     NaN  1663.0
# reward_p9   2092.0  2115.0     NaN  2616.0     NaN  1622.0
# reward_p10  2873.0  3192.0     NaN  2990.0    56.0  3468.0
# reward_p11  2417.0  2310.0     NaN  2723.0     NaN   321.0
# reward_p12  3844.0  3123.0    55.0  3481.0     NaN  2797.0
# reward_p13  3567.0  2803.0     NaN  2881.0     NaN  2306.0

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset
rewarding_patches.columns=['patch1','patch2','patch3','patch4','patch5','patch6']
rewarding_patches.drop(columns=['patch2','patch4'],inplace=True)
print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
#             patch1  patch3  patch5  patch6
# reward_p1   4736.0     NaN     NaN  4198.0
# reward_p2   3356.0    58.0     NaN  4194.0
# reward_p3   1682.0    57.0     NaN   212.0
# reward_p4   2495.0     NaN     NaN  2695.0
# reward_p5   2528.0     NaN     NaN  2528.0
# reward_p6   2723.0     NaN     NaN  2694.0
# reward_p7   3076.0    70.0     NaN  3113.0
# reward_p8    462.0     NaN     NaN  1663.0
# reward_p9   2092.0     NaN     NaN  1622.0
# reward_p10  2873.0     NaN    56.0  3468.0
# reward_p11  2417.0     NaN     NaN   321.0
# reward_p12  3844.0    55.0     NaN  2797.0
# reward_p13  3567.0     NaN     NaN  2306.0

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset
rewarding_patches.columns=['patch1','patch2','patch3','patch4','patch5','patch6']
rewarding_patches.drop(columns=['patch3','patch5'],inplace=True)
print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
#             patch1  patch2  patch4  patch6
# reward_p1   4736.0  3956.0  4278.0  4198.0
# reward_p2   3356.0  3958.0  3489.0  4194.0
# reward_p3   1682.0  2112.0   948.0   212.0
# reward_p4   2495.0  2576.0  3710.0  2695.0
# reward_p5   2528.0  2375.0  2480.0  2528.0
# reward_p6   2723.0  2965.0  2631.0  2694.0
# reward_p7   3076.0  2997.0     NaN  3113.0
# reward_p8    462.0  3668.0  3286.0  1663.0
# reward_p9   2092.0  2115.0  2616.0  1622.0
# reward_p10  2873.0  3192.0  2990.0  3468.0
# reward_p11  2417.0  2310.0  2723.0   321.0
# reward_p12  3844.0  3123.0  3481.0  2797.0
# reward_p13  3567.0  2803.0  2881.0  2306.0

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset
rewarding_patches.columns=['patch1','patch2','patch3','patch4','patch5','patch6']
rewarding_patches.drop(columns=['patch3','patch5'],inplace=True).dropna()
print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
#      19 rewarding_patches = dataset
#      20 rewarding_patches.columns=['patch1','patch2','patch3','patch4','patch5','patch6']
# ---> 21 rewarding_patches.drop(columns=['patch3','patch5'],inplace=True).dropna()
#      22 print(rewarding_patches)
#      23 # print(p2_filtered)
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset
rewarding_patches.columns=['patch1','patch2','patch3','patch4','patch5','patch6']
rewarding_patches.drop(columns=['patch3','patch5'],inplace=True)
rewarding_patches.dropna()
print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
#             patch1  patch2  patch4  patch6
# reward_p1   4736.0  3956.0  4278.0  4198.0
# reward_p2   3356.0  3958.0  3489.0  4194.0
# reward_p3   1682.0  2112.0   948.0   212.0
# reward_p4   2495.0  2576.0  3710.0  2695.0
# reward_p5   2528.0  2375.0  2480.0  2528.0
# reward_p6   2723.0  2965.0  2631.0  2694.0
# reward_p7   3076.0  2997.0     NaN  3113.0
# reward_p8    462.0  3668.0  3286.0  1663.0
# reward_p9   2092.0  2115.0  2616.0  1622.0
# reward_p10  2873.0  3192.0  2990.0  3468.0
# reward_p11  2417.0  2310.0  2723.0   321.0
# reward_p12  3844.0  3123.0  3481.0  2797.0
# reward_p13  3567.0  2803.0  2881.0  2306.0

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset
rewarding_patches.columns=['patch1','patch2','patch3','patch4','patch5','patch6']
rewarding_patches.drop(columns=['patch3','patch5'],inplace=True)
rewarding_patches.dropna(inplace=True)
print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
#             patch1  patch2  patch4  patch6
# reward_p1   4736.0  3956.0  4278.0  4198.0
# reward_p2   3356.0  3958.0  3489.0  4194.0
# reward_p3   1682.0  2112.0   948.0   212.0
# reward_p4   2495.0  2576.0  3710.0  2695.0
# reward_p5   2528.0  2375.0  2480.0  2528.0
# reward_p6   2723.0  2965.0  2631.0  2694.0
# reward_p8    462.0  3668.0  3286.0  1663.0
# reward_p9   2092.0  2115.0  2616.0  1622.0
# reward_p10  2873.0  3192.0  2990.0  3468.0
# reward_p11  2417.0  2310.0  2723.0   321.0
# reward_p12  3844.0  3123.0  3481.0  2797.0
# reward_p13  3567.0  2803.0  2881.0  2306.0

# %%
import numpy as np
import scipy 
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols

p1 = pd.read_csv('data/1.csv',skiprows=75,nrows=275-75)
p2 = pd.read_csv('data/2.csv',skiprows=75,nrows=249-75)
p3 = pd.read_csv('data/3.csv',skiprows=75,nrows=198-75)
p4 = pd.read_csv('data/4.csv',skiprows=75,nrows=275-75)
p5 = pd.read_csv('data/5.csv',skiprows=75,nrows=199-75)
p6 = pd.read_csv('data/6.csv',skiprows=75,nrows=207-75)
p7 = pd.read_csv('data/7.csv',skiprows=75,nrows=221-75)
p8 = pd.read_csv('data/8.csv',skiprows=75,nrows=247-75)
p9 = pd.read_csv('data/9.csv',skiprows=75,nrows=210-75)
p10 = pd.read_csv('data/10.csv',skiprows=75,nrows=231-75)
p11 = pd.read_csv('data/11.csv',skiprows=75,nrows=201-75)
p12 = pd.read_csv('data/12.csv',skiprows=75,nrows=257-75)
p13 = pd.read_csv('data/13.csv',skiprows=75,nrows=205-75)

# print(p1['id'])
# print(p1.iloc[0:5,0])

# %%
p1_filtered = p1.groupby(['id']).sum()
p1_filtered.columns=['exploit_p1','reward_p1']
p1_filtered.drop(p1_filtered.loc[p1_filtered['reward_p1']==0].index, inplace=True)


p2_filtered = p2.groupby(['id']).sum()
p2_filtered.columns=['exploit_p2','reward_p2']
p2_filtered.drop(p2_filtered.loc[p2_filtered['reward_p2']==0].index, inplace=True)


p3_filtered = p3.groupby(['id']).sum()
p3_filtered.columns=['exploit_p3','reward_p3']
p3_filtered.drop(p3_filtered.loc[p3_filtered['reward_p3']==0].index, inplace=True)

p4_filtered = p4.groupby(['id']).sum()
p4_filtered.columns=['exploit_p4','reward_p4']
p4_filtered.drop(p4_filtered.loc[p4_filtered['reward_p4']==0].index, inplace=True)

p5_filtered = p5.groupby(['id']).sum()
p5_filtered.columns=['exploit_p5','reward_p5']
p5_filtered.drop(p5_filtered.loc[p5_filtered['reward_p5']==0].index, inplace=True)

p6_filtered = p6.groupby(['id']).sum()
p6_filtered.columns=['exploit_p6','reward_p6']
p6_filtered.drop(p6_filtered.loc[p6_filtered['reward_p6']==0].index, inplace=True)

p7_filtered = p7.groupby(['id']).sum()
p7_filtered.columns=['exploit_p7','reward_p7']
p7_filtered.drop(p7_filtered.loc[p7_filtered['reward_p7']==0].index, inplace=True)

p8_filtered = p8.groupby(['id']).sum()
p8_filtered.columns=['exploit_p8','reward_p8']

print(p8_filtered)
p8_filtered.drop(p8_filtered.loc[p8_filtered['reward_p8']==0].index, inplace=True)
print(p8_filtered)

p9_filtered = p9.groupby(['id']).sum()
p9_filtered.columns=['exploit_p9','reward_p9']
p9_filtered.drop(p9_filtered.loc[p9_filtered['reward_p9']==0].index, inplace=True)

p10_filtered = p10.groupby(['id']).sum()
p10_filtered.columns=['exploit_p10','reward_p10']
p10_filtered.drop(p10_filtered.loc[p10_filtered['reward_p10']==0].index, inplace=True)

p11_filtered = p11.groupby(['id']).sum()
p11_filtered.columns=['exploit_p11','reward_p11']
p11_filtered.drop(p11_filtered.loc[p11_filtered['reward_p11']==0].index, inplace=True)

p12_filtered = p12.groupby(['id']).sum()
p12_filtered.columns=['exploit_p12','reward_p12']
p12_filtered.drop(p12_filtered.loc[p12_filtered['reward_p12']==0].index, inplace=True)

p13_filtered = p13.groupby(['id']).sum()
p13_filtered.columns=['exploit_p13','reward_p13']
p13_filtered.drop(p13_filtered.loc[p13_filtered['reward_p13']==0].index, inplace=True)
# Out:
#     exploit_p8  reward_p8
# id
# -1          -1       9079
#  0           3          0
#  1         137        462
#  2        2145       3668
#  3          15          0
#  4        1431       3286
#  5           3          0
#  6         325       1663
#  7           3          0
#     exploit_p8  reward_p8
# id
# -1          -1       9079
#  1         137        462
#  2        2145       3668
#  4        1431       3286
#  6         325       1663

# %%
reward1 = p1_filtered.iloc[1:,1]
reward2 = p2_filtered.iloc[1:,1]
reward3 = p3_filtered.iloc[1:,1]
reward4 = p4_filtered.iloc[1:,1]
reward5 = p5_filtered.iloc[1:,1]
reward6 = p6_filtered.iloc[1:,1]
reward7 = p7_filtered.iloc[1:,1]
reward8 = p8_filtered.iloc[1:,1]
reward9 = p9_filtered.iloc[1:,1]
reward10 = p10_filtered.iloc[1:,1]
reward11 = p11_filtered.iloc[1:,1]
reward12 = p12_filtered.iloc[1:,1]
reward13 = p13_filtered.iloc[1:,1]

dataset = pd.concat([reward1,reward2,reward3,reward4,reward5,reward6,reward7,reward8,reward9,reward10,reward11,reward12,reward13],axis=1 ).T
# print(dataset)
# dataset.to_csv('reward_per_patch.csv')

rewarding_patches = dataset
rewarding_patches.columns=['patch1','patch2','patch3','patch4','patch5','patch6']
rewarding_patches.drop(columns=['patch3','patch5'],inplace=True)
# rewarding_patches.dropna(inplace=True)
print(rewarding_patches)
# print(p2_filtered)
# print()
# Out:
#             patch1  patch2  patch4  patch6
# reward_p1   4736.0  3956.0  4278.0  4198.0
# reward_p2   3356.0  3958.0  3489.0  4194.0
# reward_p3   1682.0  2112.0   948.0   212.0
# reward_p4   2495.0  2576.0  3710.0  2695.0
# reward_p5   2528.0  2375.0  2480.0  2528.0
# reward_p6   2723.0  2965.0  2631.0  2694.0
# reward_p7   3076.0  2997.0     NaN  3113.0
# reward_p8    462.0  3668.0  3286.0  1663.0
# reward_p9   2092.0  2115.0  2616.0  1622.0
# reward_p10  2873.0  3192.0  2990.0  3468.0
# reward_p11  2417.0  2310.0  2723.0   321.0
# reward_p12  3844.0  3123.0  3481.0  2797.0
# reward_p13  3567.0  2803.0  2881.0  2306.0

# %%
df = pd.melt(rewarding_patches,value_vars=['patch1','patch2','patch3','patch4','patch5','patch6'])

df.columns = ['patches','rewards']

# print(df.sample(10))

model = ols('rewards~C(patches)',data=df).fit()
anova = sm.stats.anova_lm(model,typ=2)
print(model.summary())
print(anova)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# f:\Projects\Decision making\Working memory\reward_per_patch_code.py in <module>
# ----> 1 df = pd.melt(rewarding_patches,value_vars=['patch1','patch2','patch3','patch4','patch5','patch6'])
#       2
#       3 df.columns = ['patches','rewards']
#       4
#       5 # print(df.sample(10))
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      85             if not missing.empty:
#      86                 raise KeyError(
# ---> 87                     "The following 'value_vars' are not present in "
#      88                     f"the DataFrame: {list(missing)}"
#      89                 )
#
# KeyError: "The following 'value_vars' are not present in the DataFrame: ['patch3', 'patch5']"

# %%
df = pd.melt(rewarding_patches,value_vars=['patch1','patch2','patch4','patch6'])

df.columns = ['patches','rewards']

# print(df.sample(10))

model = ols('rewards~C(patches)',data=df).fit()
anova = sm.stats.anova_lm(model,typ=2)
print(model.summary())
print(anova)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                rewards   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                    0.7542
# Date:                Fri, 30 Jul 2021   Prob (F-statistic):              0.525
# Time:                        18:29:08   Log-Likelihood:                -421.17
# No. Observations:                  51   AIC:                             850.3
# Df Residuals:                      47   BIC:                             858.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept             2757.7692    269.797     10.222      0.000    2215.008    3300.531
# ...

# %%
sns.set_style('whitegrid') 
ax_violin= sns.violinplot(x='patches',y='rewards',data=df,inner='quartile')
ax_violin = sns.stripplot(x="patches", y="rewards",data=df)

# sns.set_style('whitegrid')
# ax_box = sns.boxplot(x='patches',y='rewards',data=df,notch=True)
# ax_box = sns.stripplot(x="patches", y="rewards",data=df)

# %%
# sns.set_style('whitegrid') 
# ax_violin= sns.violinplot(x='patches',y='rewards',data=df,inner='quartile')
# ax_violin = sns.stripplot(x="patches", y="rewards",data=df)

sns.set_style('whitegrid')
ax_box = sns.boxplot(x='patches',y='rewards',data=df,notch=True)
ax_box = sns.stripplot(x="patches", y="rewards",data=df)
